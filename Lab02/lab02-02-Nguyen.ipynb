# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv('~/Downloads/insurance.csv')

# Q1. Features and data types of this dataset
print(df.dtypes)
print("Numerical features are: age, bmi, children, charges")
print("Categorical features are: sex, smoker, region")
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
# Numerical features are: age, bmi, children, charges
# Categorical features are: sex, smoker, region

# %%
# Q2. Check whether there are missing values in this dataset.
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Q3. Visualize all numerical features with histogram plot to see the distribution of each numerical feature.
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Q4. Use corr() function of Pandas to show the correlation between different numerical features
hcorr = df.corr()
hcorr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_22ad4_row0_col0, #T_22ad4_row1_col1, #T_22ad4_row2_col2, #T_22ad4_row3_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_22ad4_row0_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_22ad4_row0_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_22ad4_row0_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_22ad4_row1_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_22ad4_row1_col2, #T_22ad4_row2_col0, #T_22ad4_row2_col1, #T_22ad4_row2_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_22ad4_row1_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_22ad4_row3_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_22ad4_row3_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_22ad4_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_22ad4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22ad4_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_22ad4_level0_col1" class="col_heading level0 col1" >bmi</th>
#       <th id="T_22ad4_level0_col2" class="col_heading level0 col2" >children</th>
#       <th id="T_22ad4_level0_col3" class="col_heading level0 col3" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22ad4_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_22ad4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_22ad4_row0_col1" class="data row0 col1" >0.109272</td>
#       <td id="T_22ad4_row0_col2" class="data row0 col2" >0.042469</td>
#       <td id="T_22ad4_row0_col3" class="data row0 col3" >0.299008</td>
#     </tr>
#     <tr>
#       <th id="T_22ad4_level0_row1" class="row_heading level0 row1" >bmi</th>
#       <td id="T_22ad4_row1_col0" class="data row1 col0" >0.109272</td>
#       <td id="T_22ad4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_22ad4_row1_col2" class="data row1 col2" >0.012759</td>
#       <td id="T_22ad4_row1_col3" class="data row1 col3" >0.198341</td>
#     </tr>
#     <tr>
#       <th id="T_22ad4_level0_row2" class="row_heading level0 row2" >children</th>
#       <td id="T_22ad4_row2_col0" class="data row2 col0" >0.042469</td>
#       <td id="T_22ad4_row2_col1" class="data row2 col1" >0.012759</td>
#       <td id="T_22ad4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_22ad4_row2_col3" class="data row2 col3" >0.067998</td>
#     </tr>
#     <tr>
#       <th id="T_22ad4_level0_row3" class="row_heading level0 row3" >charges</th>
#       <td id="T_22ad4_row3_col0" class="data row3 col0" >0.299008</td>
#       <td id="T_22ad4_row3_col1" class="data row3 col1" >0.198341</td>
#       <td id="T_22ad4_row3_col2" class="data row3 col2" >0.067998</td>
#       <td id="T_22ad4_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Q5. For all categorical features, use bar plot to visualize the number of users within each category.
df['sex'].value_counts().plot(kind = 'bar')
plt.title('sex')
plt.show()
df['smoker'].value_counts().plot(kind = 'bar')
plt.title('smoker')
plt.show()
df['region'].value_counts().plot(kind = 'bar')
plt.title('region')
plt.show()

# %%
# Q6. Convert all categorical features into numerical features with Label Encoding or One-Hot Encoding
labelencoder = LabelEncoder()
df['sex'] = labelencoder.fit_transform(df['sex'])
df['smoker'] = labelencoder.fit_transform(df['smoker'])
df['region'] = labelencoder.fit_transform(df['region'])

# %%
# Q7. Normalize all numerical features
df_min = df.min(axis=0)
df_max = df.max(axis=0)
print("\tMin: ")
print(df_min)
print("\n\tMax: ")
print(df_max)

X = (df - df_min) / (df_max - df_min)
print("\n\tScaling data")
print(X)
# Out:
# 	Min:
# age           18.0000
# sex            0.0000
# bmi           15.9600
# children       0.0000
# smoker         0.0000
# region         0.0000
# charges     1121.8739
# dtype: float64
#
# 	Max:
# age            64.00000
# sex             1.00000
# bmi            53.13000
# children        5.00000
# smoker          1.00000
# region          3.00000
# charges     63770.42801
# dtype: float64
#
# 	Scaling data
#            age  sex       bmi  children  smoker    region   charges
# 0     0.021739  0.0  0.321227       0.0     1.0  1.000000  0.251611
# 1     0.000000  1.0  0.479150       0.2     0.0  0.666667  0.009636
# 2     0.217391  1.0  0.458434       0.6     0.0  0.666667  0.053115
# 3     0.326087  1.0  0.181464       0.0     0.0  0.333333  0.333010
# 4     0.304348  1.0  0.347592       0.0     0.0  0.333333  0.043816
# ...        ...  ...       ...       ...     ...       ...       ...
# 1333  0.695652  1.0  0.403820       0.6     0.0  0.333333  0.151299
# 1334  0.000000  0.0  0.429379       0.0     0.0  0.000000  0.017305
# 1335  0.000000  0.0  0.562012       0.0     0.0  0.666667  0.008108
# 1336  0.065217  0.0  0.264730       0.0     0.0  1.000000  0.014144
# 1337  0.934783  0.0  0.352704       0.0     1.0  0.333333  0.447249
#
# [1338 rows x 7 columns]

# %%
# Q8. Save your preprocessed data into a csv file. Submit your code and the preprocessed data.
df.to_csv('preprocessed_insurance.csv', index=False)
